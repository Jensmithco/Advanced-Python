# %% [markdown]
# # Working with APIs

# %% [markdown]
# API stands for Application programming interface<br>
# APIs are a way for applications to talk to eachother<br>
# In python we use the requests package to handle the connection<br>
# <small><strong>Note: It is requests with an s not request(this is a different package)</strong></small><br>
# Most API's communicate with data in the form of JSON<br>
# JSON stands for JavaScript Object Notation

# %%
#import the packages we need:
import requests, json

# %% [markdown]
# We will be connecting to the Ergast F1 Racer API today:
# http://ergast.com/mrd/
#
# to view JSON data nicely in the Chrome browser install the extension JSONview

# %%
# help(requests)

# %%
url = 'http://ergast.com/api/f1/2008/5/driverStandings.json'

# %%
#response object
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#check and make sure we got a successful response from the API
response.ok
# Out:
# True

# %%
#view the response as a JSON
response.json()
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.5',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2008/5/driverstandings.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '22',
#   'StandingsTable': {'season': '2008',
#    'round': '5',
#    'StandingsLists': [{'season': '2008',
#      'round': '5',
#      'DriverStandings': [{'position': '1',
#        'positionText': '1',
#        'points': '35',
#        'wins': '2',
#        'Driver': {'driverId': 'raikkonen',
#         'permanentNumber': '7',
#         'code': 'RAI',
#         'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#         'givenName': 'Kimi',
#         'familyName': 'Räikkönen',
#         'dateOfBirth': '1979-10-17',
#         'nationality': 'Finnish'},
#        'Constructors': [{'constructorId': 'ferrari',
#          'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#          'name': 'Ferrari',
#          'nationality': 'Italian'}]},
#       {'position': '2',
# ...

# %%
type(response.json())
# Out:
# dict

# %%
# We only want the Driver Standings
for x in range(5):
    my_racer_data = response.json()['MRData']['StandingsTable']['StandingsLists'][0]["DriverStandings"][x]
    print(my_racer_data)
# Out:
# {'position': '1', 'positionText': '1', 'points': '35', 'wins': '2', 'Driver': {'driverId': 'raikkonen', 'permanentNumber': '7', 'code': 'RAI', 'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen', 'givenName': 'Kimi', 'familyName': 'Räikkönen', 'dateOfBirth': '1979-10-17', 'nationality': 'Finnish'}, 'Constructors': [{'constructorId': 'ferrari', 'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari', 'name': 'Ferrari', 'nationality': 'Italian'}]}
# {'position': '2', 'positionText': '2', 'points': '28', 'wins': '2', 'Driver': {'driverId': 'massa', 'permanentNumber': '19', 'code': 'MAS', 'url': 'http://en.wikipedia.org/wiki/Felipe_Massa', 'givenName': 'Felipe', 'familyName': 'Massa', 'dateOfBirth': '1981-04-25', 'nationality': 'Brazilian'}, 'Constructors': [{'constructorId': 'ferrari', 'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari', 'name': 'Ferrari', 'nationality': 'Italian'}]}
# ...

# %%
def get_racer_info(data):
    new_data = []
    for racer in data:
        racer_dict = {}
        racer_name = f"{racer['Driver']['givenName']} {racer['Driver']['familyName']}"
        
        racer_dict[racer_name]={
            'first_name':racer['Driver']['givenName'],
            'last_name':racer['Driver']['familyName'],
            'position':racer['position'],
            'wins':racer['wins'],
            'nationality':racer['Driver']['nationality'],
            'constructor':racer['Constructors'][0]['name']
        }
        new_data.append(racer_dict)
    return new_data

get_racer_info(my_racer_data)
# Out:
# [{'Kimi Räikkönen': {'first_name': 'Kimi',
#    'last_name': 'Räikkönen',
#    'position': '1',
#    'wins': '2',
#    'nationality': 'Finnish',
#    'constructor': 'Ferrari'}},
#  {'Felipe Massa': {'first_name': 'Felipe',
#    'last_name': 'Massa',
#    'position': '2',
#    'wins': '2',
#    'nationality': 'Brazilian',
#    'constructor': 'Ferrari'}},
#  {'Lewis Hamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'position': '3',
#    'wins': '1',
#    'nationality': 'British',
#    'constructor': 'McLaren'}},
#  {'Robert Kubica': {'first_name': 'Robert',
#    'last_name': 'Kubica',
#    'position': '4',
#    'wins': '0',
#    'nationality': 'Polish',
#    'constructor': 'BMW Sauber'}},
#  {'Nick Heidfeld': {'first_name': 'Nick',
#    'last_name': 'Heidfeld',
#    'position': '5',
#    'wins': '0',
#    'nationality': 'German',
#    'constructor': 'BMW Sauber'}},
#  {'Heikki Kovalainen': {'first_name': 'Heikki',
#    'last_name': 'Kovalainen',
# ...

# %%
def get_driver_info_by_year_and_round(year, r):
    url = f"https://ergast.com/api/f1/{year}/{r}/driverStandings.json"
    response = requests.get(url)
    if not response.json()["MRData"]["StandingsTable"]["StandingsLists"]:
        return "We had an error loading your data. It is likely the year or round is not in the database"
    data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
    return get_racer_info(data)

get_driver_info_by_year_and_round(2019, 4)
# Out:
# [{'Valtteri Bottas': {'first_name': 'Valtteri',
#    'last_name': 'Bottas',
#    'position': '1',
#    'wins': '1989-08-28',
#    'nationality': 'Finnish',
#    'constructor': 'Mercedes'}},
#  {'Lewis Hamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'position': '2',
#    'wins': '1985-01-07',
#    'nationality': 'British',
#    'constructor': 'Mercedes'}},
#  {'Sebastian Vettel': {'first_name': 'Sebastian',
#    'last_name': 'Vettel',
#    'position': '3',
#    'wins': '1987-07-03',
#    'nationality': 'German',
#    'constructor': 'Ferrari'}},
#  {'Max Verstappen': {'first_name': 'Max',
#    'last_name': 'Verstappen',
#    'position': '4',
#    'wins': '1997-09-30',
#    'nationality': 'Dutch',
#    'constructor': 'Red Bull'}},
#  {'Charles Leclerc': {'first_name': 'Charles',
#    'last_name': 'Leclerc',
#    'position': '5',
#    'wins': '1997-10-16',
#    'nationality': 'Monegasque',
#    'constructor': 'Ferrari'}},
# ...

# %% [markdown]
# # <strong>Homework</strong>
# check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 5 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny', attack base_state, hp base_stat, defense base_stat

# %%
poke = 'https://pokeapi.co/api/v2/pokemon/pikachu/'
pokeresponse = requests.get(poke)
print(pokeresponse)
pokeresponse.ok
# Out:
# <Response [200]>
# True

# %%
pokeresponse.json()
# Out:
# {'abilities': [{'ability': {'name': 'static',
#     'url': 'https://pokeapi.co/api/v2/ability/9/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'lightning-rod',
#     'url': 'https://pokeapi.co/api/v2/ability/31/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 112,
#  'forms': [{'name': 'pikachu',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/25/'}],
#  'game_indices': [{'game_index': 84,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 84,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 84,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 25,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 25,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 25,
# ...

# %%
pokeAbilities = pokeresponse.json()['abilities'][0]['ability']['name']
pokeAbilities2 = pokeresponse.json()['abilities'][1]['ability']['name']
pokeWeight = pokeresponse.json()['weight']
pokeNamepik = pokeresponse.json()['forms'][0]['name']
#pokeData = pokeresponse.json()[''][0]['name']
#pokeData = pokeresponse.json()['abilities'][1]['ability']['name']
#pokeData

# %%
mypokeData = pokeresponse.json()

def pokeInfo(pokedata):
    pokeDict={
        'name':pokeNamepik,
        'abilities':[pokeAbilities, pokeAbilities2],
        'weight':pokeWeight
        }
    return pokeDict

pokeInfo(mypokeData)
# Out:
# {'name': 'pikachu', 'abilities': ['static', 'lightning-rod'], 'weight': 60}

# %%
poke2 = 'https://pokeapi.co/api/v2/pokemon/charmeleon/'
pokeresponse2 = requests.get(poke2)
print(pokeresponse2)
pokeresponse2.ok
# Out:
# <Response [200]>
# True

# %%
poke2Abilities = pokeresponse2.json()['abilities'][0]['ability']['name']
poke2Abilities2 = pokeresponse2.json()['abilities'][1]['ability']['name']
poke2Weight = pokeresponse2.json()['weight']
pokeNamepik2 = pokeresponse2.json()['forms'][0]['name']

# %%
mypokeData2 = pokeresponse2.json()

def pokeInfo(pokedata2):
    pokeDict={
        'name':pokeNamepik2,
        'abilities':[poke2Abilities, poke2Abilities2],
        'weight':poke2Weight
        }
    return pokeDict

pokeInfo(mypokeData2)
# Out:
# {'name': 'charmeleon', 'abilities': ['blaze', 'solar-power'], 'weight': 190}

# %%
poke3 = 'https://pokeapi.co/api/v2/pokemon/bulbasaur/'
pokeresponse3 = requests.get(poke3)
print(pokeresponse3)
pokeresponse3.ok
# Out:
# <Response [200]>
# True

# %%
poke3Abilities = pokeresponse3.json()['abilities'][0]['ability']['name']
poke3Abilities2 = pokeresponse3.json()['abilities'][1]['ability']['name']
poke3Weight = pokeresponse3.json()['weight']
pokeNamepik3 = pokeresponse3.json()['forms'][0]['name']

# %%
mypokeData3 = pokeresponse3.json()

def pokeInfo(pokedata3):
    pokeDict={
        'name':pokeNamepik3,
        'abilities':[poke3Abilities, poke3Abilities2],
        'weight':poke3Weight
        }
    return pokeDict

pokeInfo(mypokeData3)
# Out:
# {'name': 'bulbasaur', 'abilities': ['overgrow', 'chlorophyll'], 'weight': 69}

# %%
poke4 = 'https://pokeapi.co/api/v2/pokemon/vullaby/'
pokeresponse4 = requests.get(poke4)
print(pokeresponse4)
pokeresponse4.ok
# Out:
# <Response [200]>
# True

# %%
poke4Abilities = pokeresponse4.json()['abilities'][0]['ability']['name']
poke4Abilities2 = pokeresponse4.json()['abilities'][1]['ability']['name']
poke4Abilities3 = pokeresponse4.json()['abilities'][2]['ability']['name']
poke4Weight = pokeresponse4.json()['weight']
pokeNamepik4 = pokeresponse4.json()['forms'][0]['name']

# %%
mypokeData4 = pokeresponse4.json()

def pokeInfo(pokedata4):
    pokeDict={
        'name':pokeNamepik4,
        'abilities':[poke4Abilities, poke4Abilities2, poke4Abilities3],
        'weight':poke4Weight
        }
    return pokeDict

pokeInfo(mypokeData4)
# Out:
# {'name': 'vullaby',
#  'abilities': ['big-pecks', 'overcoat', 'weak-armor'],
#  'weight': 90}

# %%
poke5 = 'https://pokeapi.co/api/v2/pokemon/butterfree/'
pokeresponse5 = requests.get(poke5)
print(pokeresponse5)
pokeresponse5.ok
# Out:
# <Response [200]>
# True

# %%
poke5Abilities = pokeresponse5.json()['abilities'][0]['ability']['name']
poke5Abilities2 = pokeresponse5.json()['abilities'][1]['ability']['name']
poke5Weight = pokeresponse5.json()['weight']
pokeNamepik5 = pokeresponse5.json()['forms'][0]['name']

# %%
mypokeData5 = pokeresponse5.json()

def pokeInfo(pokedata5):
    pokeDict={
        'name':pokeNamepik5,
        'abilities':[poke5Abilities, poke5Abilities2],
        'weight':poke5Weight
        }
    return pokeDict

pokeInfo(mypokeData5)
# Out:
# {'name': 'butterfree',
#  'abilities': ['compound-eyes', 'tinted-lens'],
#  'weight': 320}

# %%
poke6 = 'https://pokeapi.co/api/v2/pokemon/caterpie/'
pokeresponse6 = requests.get(poke6)
print(pokeresponse6)
pokeresponse6.ok
# Out:
# <Response [200]>
# True

# %%
poke6Abilities = pokeresponse6.json()['abilities'][0]['ability']['name']
poke6Abilities2 = pokeresponse6.json()['abilities'][1]['ability']['name']
poke6Weight = pokeresponse6.json()['weight']
pokeNamepik6 = pokeresponse6.json()['forms'][0]['name']

# %%
mypokeData6 = pokeresponse6.json()

def pokeInfo(pokedata6):
    pokeDict={
        'name':pokeNamepik6,
        'abilities':[poke6Abilities, poke6Abilities2],
        'weight':poke6Weight
        }
    return pokeDict

pokeInfo(mypokeData6)
# Out:
# {'name': 'caterpie', 'abilities': ['shield-dust', 'run-away'], 'weight': 29}

# %%
poke7 = 'https://pokeapi.co/api/v2/pokemon/metapod/'
pokeresponse7 = requests.get(poke7)
print(pokeresponse7)
pokeresponse7.ok
# Out:
# <Response [200]>
# True

# %%
poke7Abilities = pokeresponse7.json()['abilities'][0]['ability']['name']
poke7Weight = pokeresponse7.json()['weight']
pokeNamepik7 = pokeresponse7.json()['forms'][0]['name']

# %%
mypokeData7 = pokeresponse7.json()

def pokeInfo(pokedata7):
    pokeDict={
        'name':pokeNamepik7,
        'abilities':[poke7Abilities],
        'weight':poke7Weight
        }
    return pokeDict

pokeInfo(mypokeData7)
# Out:
# {'name': 'metapod', 'abilities': ['shed-skin'], 'weight': 99}

# %%
poke8 = 'https://pokeapi.co/api/v2/pokemon/squirtle/'
pokeresponse8 = requests.get(poke8)
print(pokeresponse8)
pokeresponse8.ok
# Out:
# <Response [200]>
# True

# %%
poke8Abilities = pokeresponse8.json()['abilities'][0]['ability']['name']
poke8Abilities2 = pokeresponse8.json()['abilities'][1]['ability']['name']
poke8Weight = pokeresponse8.json()['weight']
pokeNamepik8 = pokeresponse8.json()['forms'][0]['name']

# %%
mypokeData8 = pokeresponse8.json()

def pokeInfo(pokedata8):
    pokeDict={
        'name':pokeNamepik8,
        'abilities':[poke8Abilities, poke8Abilities2],
        'weight':poke8Weight
        }
    return pokeDict

pokeInfo(mypokeData8)
# Out:
# {'name': 'squirtle', 'abilities': ['torrent', 'rain-dish'], 'weight': 90}

# %%
poke9 = 'https://pokeapi.co/api/v2/pokemon/sandslash/'
pokeresponse9 = requests.get(poke9)
print(pokeresponse9)
pokeresponse9.ok
# Out:
# <Response [200]>
# True

# %%
poke9Abilities = pokeresponse9.json()['abilities'][0]['ability']['name']
poke9Abilities2 = pokeresponse9.json()['abilities'][1]['ability']['name']
poke9Weight = pokeresponse9.json()['weight']
pokeNamepik9 = pokeresponse9.json()['forms'][0]['name']

# %%
mypokeData9 = pokeresponse9.json()

def pokeInfo(pokedata9):
    pokeDict={
        'name':pokeNamepik9,
        'abilities':[poke9Abilities, poke9Abilities2],
        'weight':poke9Weight
        }
    return pokeDict

pokeInfo(mypokeData9)
# Out:
# {'name': 'sandslash', 'abilities': ['sand-veil', 'sand-rush'], 'weight': 295}

# %%
poke10 = 'https://pokeapi.co/api/v2/pokemon/zubat/'
pokeresponse10 = requests.get(poke10)
print(pokeresponse10)
pokeresponse10.ok
# Out:
# <Response [200]>
# True

# %%
poke10Abilities = pokeresponse10.json()['abilities'][0]['ability']['name']
poke10Abilities2 = pokeresponse10.json()['abilities'][1]['ability']['name']
poke10Weight = pokeresponse10.json()['weight']
pokeNamepik10 = pokeresponse10.json()['forms'][0]['name']

# %%
mypokeData10 = pokeresponse10.json()

def pokeInfo(pokedata10):
    pokeDict={
        'name':pokeNamepik10,
        'abilities':[poke10Abilities, poke10Abilities2],
        'weight':poke10Weight
        }
    return pokeDict

pokeInfo(mypokeData10)
# Out:
# {'name': 'zubat', 'abilities': ['inner-focus', 'infiltrator'], 'weight': 75}

# %%
poke11 = 'https://pokeapi.co/api/v2/pokemon/ninetales/'
pokeresponse11 = requests.get(poke11)
print(pokeresponse11)
pokeresponse11.ok
# Out:
# <Response [200]>
# True

# %%
poke11Abilities = pokeresponse11.json()['abilities'][0]['ability']['name']
poke11Abilities2 = pokeresponse11.json()['abilities'][1]['ability']['name']
poke11Weight = pokeresponse11.json()['weight']
pokeNamepik11 = pokeresponse11.json()['forms'][0]['name']

# %%
mypokeData11 = pokeresponse11.json()

def pokeInfo(pokedata11):
    pokeDict={
        'name':pokeNamepik11,
        'abilities':[poke11Abilities, poke11Abilities2],
        'weight':poke11Weight
        }
    return pokeDict

pokeInfo(mypokeData11)
# Out:
# {'name': 'ninetales', 'abilities': ['flash-fire', 'drought'], 'weight': 199}

# %%
poke12 = 'https://pokeapi.co/api/v2/pokemon/persian/'
pokeresponse12 = requests.get(poke12)
print(pokeresponse12)
pokeresponse12.ok
# Out:
# <Response [200]>
# True

# %%
poke12Abilities = pokeresponse12.json()['abilities'][0]['ability']['name']
poke12Abilities2 = pokeresponse12.json()['abilities'][1]['ability']['name']
poke12Abilities3 = pokeresponse12.json()['abilities'][2]['ability']['name']
poke12Weight = pokeresponse12.json()['weight']
pokeNamepik12 = pokeresponse12.json()['forms'][0]['name']

# %%
mypokeData12 = pokeresponse12.json()

def pokeInfo(pokedata12):
    pokeDict={
        'name':pokeNamepik12,
        'abilities':[poke12Abilities, poke12Abilities2, poke12Abilities3],
        'weight':poke12Weight
        }
    return pokeDict

pokeInfo(mypokeData12)
# Out:
# {'name': 'persian',
#  'abilities': ['limber', 'technician', 'unnerve'],
#  'weight': 320}

# %%
poke13 = 'https://pokeapi.co/api/v2/pokemon/xatu/'
pokeresponse13 = requests.get(poke13)
print(pokeresponse13)
pokeresponse13.ok
# Out:
# <Response [200]>
# True

# %%
poke13Abilities = pokeresponse13.json()['abilities'][0]['ability']['name']
poke13Abilities2 = pokeresponse13.json()['abilities'][1]['ability']['name']
poke13Abilities3 = pokeresponse13.json()['abilities'][2]['ability']['name']
poke13Weight = pokeresponse13.json()['weight']
pokeNamepik13 = pokeresponse13.json()['forms'][0]['name']

# %%
mypokeData13 = pokeresponse13.json()

def pokeInfo(pokedata13):
    pokeDict={
        'name':pokeNamepik13,
        'abilities':[poke13Abilities, poke13Abilities2, poke13Abilities3],
        'weight':poke13Weight
        }
    return pokeDict

pokeInfo(mypokeData13)
# Out:
# {'name': 'xatu',
#  'abilities': ['synchronize', 'early-bird', 'magic-bounce'],
#  'weight': 150}

# %%
poke14 = 'https://pokeapi.co/api/v2/pokemon/sunflora/'
pokeresponse14 = requests.get(poke14)
print(pokeresponse14)
pokeresponse14.ok
# Out:
# <Response [200]>
# True

# %%
poke14Abilities = pokeresponse14.json()['abilities'][0]['ability']['name']
poke14Abilities2 = pokeresponse14.json()['abilities'][1]['ability']['name']
poke14Abilities3 = pokeresponse14.json()['abilities'][2]['ability']['name']
poke14Weight = pokeresponse14.json()['weight']
pokeNamepik14 = pokeresponse14.json()['forms'][0]['name']

# %%
mypokeData14 = pokeresponse14.json()

def pokeInfo(pokedata14):
    pokeDict={
        'name':pokeNamepik14,
        'abilities':[poke14Abilities, poke14Abilities2, poke14Abilities3],
        'weight':poke14Weight
        }
    return pokeDict

pokeInfo(mypokeData14)
# Out:
# {'name': 'sunflora',
#  'abilities': ['chlorophyll', 'solar-power', 'early-bird'],
#  'weight': 85}

# %%
poke15 = 'https://pokeapi.co/api/v2/pokemon/breloom/'
pokeresponse15 = requests.get(poke15)
print(pokeresponse15)
pokeresponse15.ok
# Out:
# <Response [200]>
# True

# %%
poke15Abilities = pokeresponse15.json()['abilities'][0]['ability']['name']
poke15Abilities2 = pokeresponse15.json()['abilities'][1]['ability']['name']
poke15Abilities3 = pokeresponse15.json()['abilities'][2]['ability']['name']
poke15Weight = pokeresponse15.json()['weight']
pokeNamepik15 = pokeresponse15.json()['forms'][0]['name']

# %%
mypokeData15 = pokeresponse15.json()

def pokeInfo(pokedata15):
    pokeDict={
        'name':pokeNamepik15,
        'abilities':[poke15Abilities, poke15Abilities2, poke15Abilities3],
        'weight':poke15Weight
        }
    return pokeDict

pokeInfo(mypokeData15)
# Out:
# {'name': 'breloom',
#  'abilities': ['effect-spore', 'poison-heal', 'technician'],
#  'weight': 392}

# %%
poke16 = 'https://pokeapi.co/api/v2/pokemon/espeon/'
pokeresponse16 = requests.get(poke16)
print(pokeresponse16)
pokeresponse16.ok
# Out:
# <Response [200]>
# True

# %%
poke16Abilities = pokeresponse16.json()['abilities'][0]['ability']['name']
poke16Abilities2 = pokeresponse16.json()['abilities'][1]['ability']['name']
poke16Weight = pokeresponse16.json()['weight']
pokeNamepik16 = pokeresponse16.json()['forms'][0]['name']

# %%
mypokeData16 = pokeresponse16.json()

def pokeInfo(pokedata16):
    pokeDict={
        'name':pokeNamepik16,
        'abilities':[poke16Abilities, poke16Abilities2],
        'weight':poke16Weight
        }
    return pokeDict

pokeInfo(mypokeData16)
# Out:
# {'name': 'espeon', 'abilities': ['synchronize', 'magic-bounce'], 'weight': 265}

# %%
poke17 = 'https://pokeapi.co/api/v2/pokemon/murkrow/'
pokeresponse17 = requests.get(poke17)
print(pokeresponse17)
pokeresponse17.ok
# Out:
# <Response [200]>
# True

# %%
poke17Abilities = pokeresponse17.json()['abilities'][0]['ability']['name']
poke17Abilities2 = pokeresponse17.json()['abilities'][1]['ability']['name']
poke17Abilities3 = pokeresponse17.json()['abilities'][2]['ability']['name']
poke17Weight = pokeresponse17.json()['weight']
pokeNamepik17 = pokeresponse17.json()['forms'][0]['name']

# %%
mypokeData17 = pokeresponse17.json()

def pokeInfo(pokedata17):
    pokeDict={
        'name':pokeNamepik17,
        'abilities':[poke17Abilities, poke17Abilities2, poke17Abilities3],
        'weight':poke17Weight
        }
    return pokeDict

pokeInfo(mypokeData17)
# Out:
# {'name': 'murkrow',
#  'abilities': ['insomnia', 'super-luck', 'prankster'],
#  'weight': 21}

# %%
poke18 = 'https://pokeapi.co/api/v2/pokemon/ursaring/'
pokeresponse18 = requests.get(poke18)
print(pokeresponse18)
pokeresponse18.ok
# Out:
# <Response [200]>
# True

# %%
poke18Abilities = pokeresponse18.json()['abilities'][0]['ability']['name']
poke18Abilities2 = pokeresponse18.json()['abilities'][1]['ability']['name']
poke18Abilities3 = pokeresponse18.json()['abilities'][2]['ability']['name']
poke18Weight = pokeresponse18.json()['weight']
pokeNamepik18 = pokeresponse18.json()['forms'][0]['name']

# %%
mypokeData18 = pokeresponse18.json()

def pokeInfo(pokedata18):
    pokeDict={
        'name':pokeNamepik18,
        'abilities':[poke18Abilities, poke18Abilities2, poke18Abilities3],
        'weight':poke18Weight
        }
    return pokeDict

pokeInfo(mypokeData18)
# Out:
# {'name': 'ursaring',
#  'abilities': ['guts', 'quick-feet', 'unnerve'],
#  'weight': 1258}

# %%
poke19 = 'https://pokeapi.co/api/v2/pokemon/delibird/'
pokeresponse19 = requests.get(poke19)
print(pokeresponse19)
pokeresponse19.ok
# Out:
# <Response [200]>
# True

# %%
poke19Abilities = pokeresponse19.json()['abilities'][0]['ability']['name']
poke19Abilities2 = pokeresponse19.json()['abilities'][1]['ability']['name']
poke19Abilities3 = pokeresponse19.json()['abilities'][2]['ability']['name']
poke19Weight = pokeresponse19.json()['weight']
pokeNamepik19 = pokeresponse19.json()['forms'][0]['name']

# %%
mypokeData19 = pokeresponse19.json()

def pokeInfo(pokedata19):
    pokeDict={
        'name':pokeNamepik19,
        'abilities':[poke19Abilities, poke19Abilities2, poke19Abilities3],
        'weight':poke19Weight
        }
    return pokeDict

pokeInfo(mypokeData19)
# Out:
# {'name': 'delibird',
#  'abilities': ['vital-spirit', 'hustle', 'insomnia'],
#  'weight': 160}

# %%
poke20 = 'https://pokeapi.co/api/v2/pokemon/cacturne/'
pokeresponse20 = requests.get(poke20)
print(pokeresponse20)
pokeresponse20.ok
# Out:
# <Response [200]>
# True

# %%
poke20Abilities = pokeresponse20.json()['abilities'][0]['ability']['name']
poke20Abilities2 = pokeresponse20.json()['abilities'][1]['ability']['name']
poke20Weight = pokeresponse20.json()['weight']
pokeNamepik20 = pokeresponse20.json()['forms'][0]['name']

# %%
mypokeData20 = pokeresponse20.json()

def pokeInfo(pokedata20):
    pokeDict={
        'name':pokeNamepik20,
        'abilities':[poke20Abilities, poke20Abilities2],
        'weight':poke20Weight
        }
    return pokeDict

pokeInfo(mypokeData20)
# Out:
# {'name': 'cacturne', 'abilities': ['sand-veil', 'water-absorb'], 'weight': 774}
