# %% [markdown]
# # Nba Regular Season 2018-19 Data Challenge
#
# Your task will be to take the dataset given, and create an analysis answering the following 10 questions. This project will again test your knowledge of pandas in order to find the answers needed given the data you are presented with.

# %% [markdown]
# # What was the average age of player in the league?

# %%
import pandas as pd
import numpy as np

# %%
nbachal = pd.read_csv(r'C:\Users\jnics\Pandas\nbastats2018-2019.csv', sep = ',')
nbachal.describe(include = 'all')
# Out:
#                 Name      Height      Weight           Team         Age  \
# count            521  521.000000  521.000000            470  521.000000
# unique           521         NaN         NaN             30         NaN
# top     Alex Abrines         NaN         NaN  Atlanta Hawks         NaN
# freq               1         NaN         NaN             21         NaN
# mean             NaN   78.971209  217.516315            NaN   25.900192
# std              NaN    3.299932   23.522089            NaN    4.208236
# min              NaN   69.000000  166.000000            NaN   19.000000
# 25%              NaN   77.000000  200.000000            NaN   23.000000
# 50%              NaN   79.000000  215.000000            NaN   25.000000
# 75%              NaN   82.000000  235.000000            NaN   29.000000
# max              NaN   87.000000  290.000000            NaN   42.000000
#
#        Salary      Points      Blocks      Steals     Assists  ...  \
# ...

# %%
#Answer: 25.9

# %% [markdown]
# # What player scored the most points?

# %%
playerPoints = nbachal['Points'].sort_values()
playerPoints
nbachal[202:203]
# Out:
#              Name  Height  Weight             Team  Age    Salary  Points  \
# 202  James Harden      77     220  Houston Rockets   29  30431854    36.1
#
#      Blocks  Steals  Assists  ...    MP   G   PER   OWS  DWS    WS   WS48  \
# 202     0.7     2.0      7.5  ...  36.8  78  30.6  11.4  3.8  15.2  0.254
#
#       USG   BPM  VORP
# 202  40.5  11.7   9.9
#
# [1 rows x 27 columns]

# %%
#Answer: James Harden

# %% [markdown]
# # What player had the most blocks during the season? Was it a post player (F/C)?

# %%
playerBlocks = nbachal['Blocks'].sort_values()
playerBlocks
nbachal[476:477]
# Out:
#              Name  Height  Weight            Team  Age   Salary  Points  \
# 476  Myles Turner      83     250  Indiana Pacers   22  3410284    13.3
#
#      Blocks  Steals  Assists  ...    MP   G   PER  OWS  DWS   WS   WS48   USG  \
# 476     2.7     0.8      1.6  ...  28.6  74  18.0  1.9  4.4  6.3  0.144  20.0
#
#      BPM  VORP
# 476  3.3   2.8
#
# [1 rows x 27 columns]

# %%
#Answer: Myles Turner, yes

# %% [markdown]
# # Based on the regular season, who had the best chance to win a title given their win percentage?

# %%
playerBlocks = nbachal['WS'].sort_values()
playerBlocks
nbachal[202:203]
# Out:
#              Name  Height  Weight             Team  Age    Salary  Points  \
# 202  James Harden      77     220  Houston Rockets   29  30431854    36.1
#
#      Blocks  Steals  Assists  ...    MP   G   PER   OWS  DWS    WS   WS48  \
# 202     0.7     2.0      7.5  ...  36.8  78  30.6  11.4  3.8  15.2  0.254
#
#       USG   BPM  VORP
# 202  40.5  11.7   9.9
#
# [1 rows x 27 columns]

# %%
#Answer: James Harden

# %% [markdown]
# # What player had the best 3-pt percentage?

# %%
player3pt = nbachal['FG%'].sort_values()
player3pt
#nbachal[405:406]
nbachal[439:440]
# Out:
#               Name  Height  Weight           Team  Age Salary  Points  Blocks  \
# 439  Jordan Sibert      76     187  Atlanta Hawks   26  47371     3.0     0.0
#
#      Steals  Assists  ...   MP  G   PER  OWS  DWS   WS   WS48   USG  BPM  VORP
# 439     0.0      0.0  ...  4.0  1  29.7  0.0  0.0  0.0  0.183  10.2  6.3   0.0
#
# [1 rows x 27 columns]

# %%
#Answer: Tie: Zhou Qi, Jordan Sibert

# %% [markdown]
# # Who played the most minutes during the season

# %%
#MP
playermt = nbachal['MP'].sort_values()
playermt
nbachal[179:180]
# Out:
#             Name  Height  Weight                   Team  Age    Salary  \
# 179  Paul George      81     220  Oklahoma City Thunder   28  30560700
#
#      Points  Blocks  Steals  Assists  ...    MP   G   PER  OWS  DWS    WS  \
# 179    28.0     0.4     2.2      4.1  ...  36.9  77  23.3  7.0  4.9  11.9
#
#       WS48   USG  BPM  VORP
# 179  0.201  29.5  5.5   5.3
#
# [1 rows x 27 columns]

# %%
#Answer: Paul George

# %% [markdown]
# # What player given their player effiecency rating was the clutchest during the season?

# %%
playerPER = nbachal['PER'].sort_values()
playerPER
nbachal[405:406]
# Out:
#         Name  Height  Weight             Team  Age  Salary  Points  Blocks  \
# 405  Zhou Qi      85     210  Houston Rockets   23  506134     2.0     0.0
#
#      Steals  Assists  ...   MP  G   PER  OWS  DWS   WS   WS48   USG  BPM  VORP
# 405     0.0      0.0  ...  1.0  1  80.4  0.0  0.0  0.0  1.261  43.4  9.5   0.0
#
# [1 rows x 27 columns]

# %%
#Answer: Zhou Qi

# %% [markdown]
# # What team had the youngest roster?

# %%
nbachal.groupby('Team', as_index = False).mean()[['Team','Age']]
# Out:
#                       Team        Age
# 0            Atlanta Hawks  26.476190
# 1           Boston Celtics  25.600000
# 2            Brooklyn Nets  25.555556
# 3        Charlotte Hornets  26.000000
# 4            Chicago Bulls  24.312500
# 5      Cleveland Cavaliers  26.000000
# 6         Dallas Mavericks  27.866667
# 7           Denver Nuggets  25.266667
# 8          Detroit Pistons  26.266667
# 9    Golden State Warriors  27.866667
# 10         Houston Rockets  27.923077
# 11          Indiana Pacers  25.058824
# 12    Los Angeles Clippers  27.105263
# 13      Los Angeles Lakers  26.625000
# 14       Memphis Grizzlies  25.647059
# 15              Miami Heat  28.181818
# 16         Milwaukee Bucks  26.928571
# 17  Minnesota Timberwolves  26.625000
# 18    New Orleans Pelicans  25.777778
# 19         New York Knicks  24.625000
# 20   Oklahoma City Thunder  25.750000
# 21           Orlando Magic  24.533333
# 22      Philadelphia 76ers  26.352941
# 23            Phoenix Suns  24.761905
# ...

# %%
#Answer: Chicago Bulls

# %% [markdown]
# # Who is the highest paid player during the seasion?

# %%
nbachal['Salary'] = nbachal['Salary'].convert_dtypes()
nbachal['Salary'] = pd.to_numeric(nbachal['Salary'], errors = 'coerce')
nbachal['Salary'] = pd.to_numeric(nbachal['Salary'], errors = 'coerce').convert_dtypes()
print(nbachal)

topearningPlayers = nbachal.sort_values(by = 'Salary', ascending= False, kind = 'mergesort')
topearningPlayer = topearningPlayers.head(1)[['Name', 'Team', 'Salary', 'Age']]
topearningPlayer.reset_index(drop = True)
# Out:
#              Name  Height  Weight                   Team  Age    Salary  \
# 0    Alex Abrines      78     200  Oklahoma City Thunder   25   5455236
# 1      Quincy Acy      79     240           Phoenix Suns   28    213949
# 2    Jaylen Adams      74     190          Atlanta Hawks   22    236854
# 3    Steven Adams      84     265  Oklahoma City Thunder   25  24157304
# 4     Bam Adebayo      82     255             Miami Heat   21   2955840
# ..            ...     ...     ...                    ...  ...       ...
# 516    Trae Young      74     180          Atlanta Hawks   20   5356440
# 517   Cody Zeller      84     240      Charlotte Hornets   26  13528090
# 518  Tyler Zeller      84     253          Atlanta Hawks   29    106974
# 519    Ante Zizic      83     254    Cleveland Cavaliers   22   1952760
# 520   Ivica Zubac      85     240   Los Angeles Clippers   21   1544951
#
#      Points  Blocks  Steals  Assists  ...    MP   G   PER  OWS  DWS   WS  \
# ...

# %%
#Answer: Stephen Curry

# %% [markdown]
# # At the end of a game, who WOULDN'T you want on the Free Throw Line?

# %%
#FT%
#lownba = nbachal['FT%'].sort_values()
#lownba
newnba = nbachal[nbachal['FT%'] > 0]
playerLeast = newnba['FT%'].sort_values()
playerLeast
nbachal[168:169]
# Out:
#                Name  Height  Weight           Team  Age   Salary  Points  \
# 168  Melvin Frazier      78     200  Orlando Magic   22  1050000     1.5
#
#      Blocks  Steals  Assists  ...   MP   G  PER  OWS  DWS   WS   WS48   USG  \
# 168     0.0     0.1      0.1  ...  4.4  10  1.2 -0.2  0.0 -0.1 -0.133  23.5
#
#       BPM  VORP
# 168 -12.9  -0.1
#
# [1 rows x 27 columns]

# %%
#Answer: Melvin Frazier
