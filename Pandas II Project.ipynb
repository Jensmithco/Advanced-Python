# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidance to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this intire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to similate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv(r'C:\Users\jnics\Pandas\AB_NYC_2019.csv')
air_bnb.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
# How many neighborhood groups are available and which shows up the most?
air_bnb.groupby('neighbourhood_group').count()
# Out:
#                         id   name  host_id  host_name  neighbourhood  \
# neighbourhood_group
# Bronx                 1091   1090     1091       1090           1091
# Brooklyn             20104  20098    20104      20095          20104
# Manhattan            21661  21652    21661      21652          21661
# Queens                5666   5666     5666       5664           5666
# Staten Island          373    373      373        373            373
#
#                      latitude  longitude  room_type  price  minimum_nights  \
# neighbourhood_group
# Bronx                    1091       1091       1091   1091            1091
# Brooklyn                20104      20104      20104  20104           20104
# Manhattan               21661      21661      21661  21661           21661
# Queens                   5666       5666       5666   5666            5666
# Staten Island             373        373        373    373             373
#
# ...

# %%
#Answer: 5 neighborhood groups, Manhattan

# %%
# Are private rooms the most popular in manhattan?
air_bnb.groupby(['room_type','neighbourhood_group']).mean().sort_values('room_type')
# Out:
#                                                id       host_id   latitude  \
# room_type       neighbourhood_group
# Entire home/apt Bronx                2.269787e+07  1.037373e+08  40.848013
#                 Brooklyn             1.730117e+07  4.861704e+07  40.685211
#                 Manhattan            1.866860e+07  6.557697e+07  40.758266
#                 Queens               2.112772e+07  8.713280e+07  40.728993
#                 Staten Island        2.170833e+07  9.618779e+07  40.605728
# Private room    Bronx                2.235896e+07  1.060786e+08  40.849158
#                 Brooklyn             1.894125e+07  6.242636e+07  40.685513
#                 Manhattan            1.880759e+07  6.982314e+07  40.776002
#                 Queens               2.197231e+07  1.008169e+08  40.732940
#                 Staten Island        2.106201e+07  1.017539e+08  40.614450
# Shared room     Bronx                2.705442e+07  1.123450e+08  40.840873
# ...

# %%
#Answer: No

# %%
# Which hosts are the busiest and based on their reviews?

busiest = air_bnb['reviews_per_month'].max()
busiestairbnb = air_bnb[air_bnb['reviews_per_month'] >= 58]
busiestairbnb
# Out:
#              id                                               name    host_id  \
# 42075  32678719  Enjoy great views of the City in our Deluxe Room!  244361589
#
#       host_name neighbourhood_group     neighbourhood  latitude  longitude  \
# 42075   Row NYC           Manhattan  Theater District  40.75918  -73.98801
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 42075  Private room    100               1                156  2019-07-07
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 42075               58.5                               9               299

# %%
#Answer: Row NYC

# %%
#Which neighorhood group has the highest average price?

air_bnb.groupby(['price','neighbourhood_group']).mean().sort_values('price')
# Out:
#                                      id       host_id   latitude  longitude  \
# price neighbourhood_group
# 0     Bronx                2.033347e+07  1.316976e+08  40.832960 -73.886680
#       Brooklyn             2.055804e+07  5.549736e+07  40.694308 -73.924413
#       Manhattan            2.093385e+07  1.370929e+07  40.750910 -73.975970
# 10    Bronx                2.731667e+07  2.058208e+08  40.834540 -73.927510
#       Brooklyn             2.601194e+07  1.035098e+08  40.697907 -73.949197
# ...                                 ...           ...        ...        ...
# 8500  Manhattan            2.337741e+07  1.812846e+07  40.721970 -74.006330
# 9999  Manhattan            1.520238e+07  3.174554e+06  40.741997 -73.969903
# 10000 Manhattan            2.243690e+07  7.239039e+07  40.772130 -73.986650
#       Brooklyn             1.389434e+07  5.143901e+06  40.732600 -73.957390
#       Queens               7.003697e+06  2.058283e+07  40.768100 -73.916510
#
# ...

# %%
#Answer: Manhattan

# %%
# Which neighbor hood group has the highest total price?
neighborprice = air_bnb[air_bnb['price'] >= 10000]
neighborprice
# Out:
#              id                                             name   host_id  \
# 9151    7003697              Furnished room in Astoria apartment  20582832
# 17692  13894339  Luxury 1 bedroom apt. -stunning Manhattan views   5143901
# 29238  22436899                              1-BR Lincoln Center  72390391
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 9151   Kathrine              Queens          Astoria  40.76810  -73.91651
# 17692      Erin            Brooklyn       Greenpoint  40.73260  -73.95739
# 29238    Jelena           Manhattan  Upper West Side  40.77213  -73.98665
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 9151      Private room  10000             100                  2  2016-02-13
# 17692  Entire home/apt  10000               5                  5  2017-07-27
# 29238  Entire home/apt  10000              30                  0         NaN
#
# ...

# %%
#Answer: Queens, Brooklyn and Manhattan tied

# %%
#Which top 5 hosts have the highest total price?
hostprice = air_bnb[air_bnb['price'] >= 9000]
hostprice
# Out:
#              id                                               name   host_id  \
# 6530    4737930                                 Spanish Harlem Apt   1235070
# 9151    7003697                Furnished room in Astoria apartment  20582832
# 12342   9528920                Quiet, Clean, Lit @ LES & Chinatown   3906464
# 17692  13894339    Luxury 1 bedroom apt. -stunning Manhattan views   5143901
# 29238  22436899                                1-BR Lincoln Center  72390391
# 40433  31340283  2br - The Heart of NYC: Manhattans Lower East ...   4382127
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 6530      Olson           Manhattan      East Harlem  40.79264  -73.93898
# 9151   Kathrine              Queens          Astoria  40.76810  -73.91651
# 12342       Amy           Manhattan  Lower East Side  40.71355  -73.98507
# 17692      Erin            Brooklyn       Greenpoint  40.73260  -73.95739
# ...

# %%
#Answer:Jelena, Erin, Kathrine, Olson, Matt, Amy(tie)

# %%
# Who currently has no (zero) availability with a review count of 100 or more?
host = air_bnb[air_bnb['number_of_reviews'] >= 100]
host
hostanswer = host[host['availability_365'] == 0]
hostanswer
# Out:
#              id                                       name    host_id  \
# 8          5203         Cozy Clean Guest Room - Family Apt       7490
# 94        20913         Charming 1 bed GR8 WBurg LOCATION!      79402
# 132       30031           NYC artists’ loft with roof deck     129352
# 174       44221             Financial District Luxury Loft     193722
# 180       45556      Fort Greene, Brooklyn: Center Bedroom      67778
# ...         ...                                        ...        ...
# 29581  22705516         The Quietest Block in Manhattan :)  127740507
# 30461  23574142                          queens get away!!  176185168
# 31250  24267706  entire sunshine of the spotless mind room   21074914
# 32670  25719044                COZY Room for Female Guests   40119874
# 35014  27759146     Cozy corner near Empire State Building  209549523
#
#         host_name neighbourhood_group              neighbourhood  latitude  \
# ...

# %%
# What host has the highest total of prices and where are they located?
air_bnb['price'].sum()
# Out:
# 7467278

# %%
# When did Danielle from Queens last receive a review?
hostreview = air_bnb[air_bnb['host_name'] == 'Danielle']

daniellebnb = hostreview['last_review'].sort_values(ascending=False)
daniellebnb 
#last_review
# Out:
# 22469    2019-07-08
# 21517    2019-07-07
# 20403    2019-07-06
# 5717     2019-07-06
# 29546    2019-07-06
#             ...
# 16349           NaN
# 34760           NaN
# 37221           NaN
# 43825           NaN
# 48533           NaN
# Name: last_review, Length: 76, dtype: object

# %%
#Answer: 2019-07-08

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %%
listings = air_bnb.groupby('host_id').count()
listings['id'].sort_values(ascending=False)

air_bnb[air_bnb['host_id'] == 219517861]
# Out:
#              id                                               name    host_id  \
# 38293  30181691      Sonder | 180 Water | Incredible 2BR + Rooftop  219517861
# 38294  30181945         Sonder | 180 Water | Premier 1BR + Rooftop  219517861
# 38588  30347708        Sonder | 180 Water | Charming 1BR + Rooftop  219517861
# 39769  30937590            Sonder | The Nash | Artsy 1BR + Rooftop  219517861
# 39770  30937591        Sonder | The Nash | Lovely Studio + Rooftop  219517861
# ...         ...                                                ...        ...
# 47691  35871510  Sonder | 116 John | Vibrant Studio + Fitness Room  219517861
# 47692  35871511     Sonder | 116 John | Vibrant 1BR + Fitness Room  219517861
# 47693  35871515         Sonder | 116 John | Stunning 1BR + Rooftop  219517861
# 47814  35936418          Sonder | 116 John | Polished Studio + Gym  219517861
# 47821  35937891            Sonder | 116 John | Simple Studio + Gym  219517861
#
# ...

# %%
#Answer: host id 219517861, Sonder (NYC)

# %% [markdown]
# 2. How many listings have completely open availability?

# %%
air_bnb[air_bnb['availability_365'] == 365]
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 36        11452                        Clean and Quiet in Brooklyn       7355
# 38        11943                          Country space in the city      45445
# 97        21644                          Upper Manhattan, New York      82685
# ...         ...                                                ...        ...
# 48744  36415840         A BEAUTIFUL SPACE IN HEART OF WILLIAMSBURG  223715460
# 48844  36453952    West Village Studio on quiet cobblestone street  115491896
# 48868  36473253                       Heaven for you(only for guy)  261338177
# 48880  36481315  The Raccoon Artist Studio in Williamsburg New ...  208514239
# 48887  36483152    Garden Jewel Apartment in Williamsburg New York  208514239
#
# ...

# %%
#Answer: 1295

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %%
air_bnb.groupby(['room_type','number_of_reviews']).count().sort_values('number_of_reviews')
# Out:
#                                      id  name  host_id  host_name  \
# room_type       number_of_reviews
# Entire home/apt 0                  5077  5075     5077       5074
# Shared room     0                   314   313      314        314
# Private room    0                  4661  4654     4661       4659
#                 1                  2554  2554     2554       2552
# Shared room     1                   137   137      137        137
# ...                                 ...   ...      ...        ...
# Private room    576                   1     1        1          1
#                 594                   1     1        1          1
#                 597                   1     1        1          1
#                 607                   1     1        1          1
#                 629                   1     1        1          1
#
#                                    neighbourhood_group  neighbourhood  \
# room_type       number_of_reviews
# ...

# %%
#Answer: Private room

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --

# %%
# The highest average price was in Manhattan.
# Sonder in NYC had the most listings
# The highest reviews were for private rooms
# There were 5 neighborhood groups and the one with the most listings was Manhattan
# Manhattan had the highest average price listing
